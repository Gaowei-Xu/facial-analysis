# %%
import os
import json
import cv2
import numpy as np
import matplotlib.pyplot as plt


landmarks_color_mapping = {
    "eyeLeft": "#00FFFF", "eyeRight": "#F5F5DC", "mouthLeft": "#FFEBCD",
    "mouthRight": "#A52A2A", "nose": "#7FFF00", "leftEyeBrowLeft": "#6495ED",
    "leftEyeBrowRight": "#00FFFF", "leftEyeBrowUp": "#B8860B", "rightEyeBrowLeft": "#BDB76B", 
    "rightEyeBrowRight": "#FF8C00", "rightEyeBrowUp": "#E9967A", "leftEyeLeft": "#2F4F4F",
    "leftEyeRight": "#FF1493", "leftEyeUp": "#1E90FF", "leftEyeDown": "#228B22",
    "rightEyeLeft": "#F8F8FF", "rightEyeRight": "#808080", "rightEyeUp": "#F0FFF0",
    "rightEyeDown": "#4B0082", "noseLeft": "#E6E6FA", "noseRight": "#FFFACD",
    "mouthUp": "#E0FFFF", "mouthDown": "#D3D3D3", "leftPupil": "#20B2AA",
    "rightPupil": "#B0C4DE", "upperJawlineLeft": "#32CD32", "midJawlineLeft": "#800000",
    "chinBottom": "#BA55D3", "midJawlineRight": "#7B68EE", "upperJawlineRight": "#C71585"
}

frames_root_dir = './raw_volvo_demo_video_frames/'
face_detection_results_root_dir = './face_detection_results/'

frames = [ele for ele in os.listdir(frames_root_dir) if ele.endswith('.jpg')]
frames = sorted(frames, key=lambda x: int(x.split('.jpg')[0]))

output_frames_root_dir = './output/frames/'
if not os.path.exists(output_frames_root_dir):
    os.makedirs(output_frames_root_dir)

for frame_name in frames[4090:]:
    print('Processing frame {}'.format(frame_name))

    image = cv2.imread(os.path.join(frames_root_dir, frame_name), cv2.IMREAD_COLOR)
    image_height = image.shape[0]
    image_width = image.shape[1]
    
    with open(os.path.join(face_detection_results_root_dir, frame_name.split('.jpg')[0] + '.json'), 'r') as rf:
        response = json.load(rf)
    
    face_details = response['FaceDetails']

    fig = plt.figure(figsize=(19.2, 10.8))
    ax = fig.add_subplot(111)
    plt.imshow(image[:, :, ::-1])
    plt.axis('off')
    texts = list()
            
    # draw bounding boxes and landmarks
    for face_index in range(len(face_details)):
        height = int(face_details[face_index]['BoundingBox']['Height'] * image_height)
        left = int(face_details[face_index]['BoundingBox']['Left'] * image_width)
        top = int(face_details[face_index]['BoundingBox']['Top'] * image_height)
        width = int(face_details[face_index]['BoundingBox']['Width'] * image_width)
        
        # get attributes
        face_prob = round(face_details[face_index]['Confidence'], 2)
        gender = face_details[face_index]['Gender']['Value']
        age_low = face_details[face_index]['AgeRange']['Low']
        age_high = face_details[face_index]['AgeRange']['High']
        emo_list = face_details[face_index]['Emotions']
        emo_list = sorted(emo_list, key=lambda x: -x['Confidence'])
        emotion = emo_list[0]['Type']
        wearglasses = 'Yes' if face_details[face_index]['Sunglasses']['Value'] is True or face_details[face_index]['Eyeglasses']['Value'] is True else 'No'
        mustache = 'Yes' if face_details[face_index]['Mustache']['Value'] is True else 'No'
        beard = 'Yes' if face_details[face_index]['Beard']['Value'] is True else 'No'
        pitch = round(face_details[face_index]['Pose']['Pitch'], 1)
        roll = round(face_details[face_index]['Pose']['Roll'], 1)
        yaw = round(face_details[face_index]['Pose']['Yaw'], 1)

        # (left, top)
        # (left + width, top + height)
        x_min, y_min, x_max, y_max = left, top, left + width, top + height
        x_min = 0 if x_min < 0 else x_min
        x_min = image_width - 1 if x_min >= image_width else x_min
        y_min = 0 if y_min < 0 else y_min
        y_min = image_height - 1 if y_min >= image_height else y_min
        
        x_max = 0 if x_max < 0 else x_max
        x_max = image_width - 1 if x_max >= image_width else x_max
        y_max = 0 if y_max < 0 else y_max
        y_max = image_height - 1 if y_max >= image_height else y_max
        
        rect = plt.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min, fill=True,
                          edgecolor=None, linewidth=1, facecolor='#FFFFE0', alpha=0.10)
        ax.add_patch(rect)
        
        if gender == 'Male':
            rect = plt.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min, color='#7FFFD4', fill=False, linewidth=1.5)
            ax.add_patch(rect)
        else:
            rect = plt.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min, color='#DB7093', fill=False, linewidth=1.5)
            ax.add_patch(rect) 
        
        # draw landmarks
        landmarks = face_details[face_index]['Landmarks']
        for mark in landmarks:
            x = int(mark['X'] * image_width)
            y = int(mark['Y'] * image_height)
            point_type = mark['Type']
            if x >= 3 and x < image_width - 3 and y >= 3 and y < image_height:
                plt.plot(x, y, '.', color=landmarks_color_mapping[point_type])
        
        # place text to describe the face attributes  
        text_position = None

        text_area_candidates = [
            [left + width + 8, top, left + width + 8 + 210, top + 210],  # 右侧顶端对齐
            [left - 200, top, left, top + 210],  # 左侧顶端对齐
            [left, top + height + 8, left + 210, top + height + 8 + 210],# 下侧左端对齐
            [left, top - 200, left + 210, top],  # 上侧左端对齐
            [left + width + 8, top + height + 8, left + width + 8 + 210, top + height + 8 + 210], # 右下侧左端对齐
            [left - 200, top + height + 8, left, top + height + 8 + 210], # 左下侧右侧对齐
            [left - 200, top - 210, left, top], # 左上侧右侧（底部）对齐
            [left + width + 8, top - 210, left + width + 8 + 210, top] #右上侧对齐
        ]
        
        margin = 40
        for area in text_area_candidates:
            if area[0] > margin and area[1] > margin and area[2] < image_width - margin and area[3] < image_height - margin:
                text_position = area
                break
    
        if text_position is None:
            continue
        
        plt.text(text_position[0], text_position[1], 
                 "-Face Prob: {}%\n-Gender: {}\n-Age: {}~{} years old\n-Emotion: {}\n-Wear Glasses: {}\n-Mustache: {}\n-Beard: {}\n-Pose: {}/{}/{}".format(
                     face_prob,
                     gender,
                     age_low, age_high,
                     emotion,
                     wearglasses,
                     mustache,
                     beard,
                     pitch,
                     roll,
                     yaw
                 ), 
                 size = 8, color = "#FFD700", weight = 'bold', ha = 'left', va = 'top', in_layout=True,
                 bbox = dict(boxstyle = 'round', facecolor = "#FF00FF", alpha = 0.2))
    
    fig.savefig(os.path.join(output_frames_root_dir, frame_name),
                transparent=True, dpi=300, pad_inches=0, bbox_inches='tight')
    plt.close()
# Out:
# Processing frame 4090.jpg
# Processing frame 4091.jpg
# Processing frame 4092.jpg
# Processing frame 4093.jpg
# Processing frame 4094.jpg
# Processing frame 4095.jpg
# Processing frame 4096.jpg
# Processing frame 4097.jpg
# Processing frame 4098.jpg
# Processing frame 4099.jpg
# Processing frame 4100.jpg
# Processing frame 4101.jpg
# Processing frame 4102.jpg
# Processing frame 4103.jpg
# Processing frame 4104.jpg
# Processing frame 4105.jpg
# Processing frame 4106.jpg
# Processing frame 4107.jpg
# Processing frame 4108.jpg
# Processing frame 4109.jpg
# Processing frame 4110.jpg
# Processing frame 4111.jpg
# Processing frame 4112.jpg
# Processing frame 4113.jpg
# Processing frame 4114.jpg
# Processing frame 4115.jpg
# Processing frame 4116.jpg
# Processing frame 4117.jpg
# Processing frame 4118.jpg
# Processing frame 4119.jpg
# Processing frame 4120.jpg
# Processing frame 4121.jpg
# Processing frame 4122.jpg
# Processing frame 4123.jpg
# Processing frame 4124.jpg
# Processing frame 4125.jpg
# Processing frame 4126.jpg
# Processing frame 4127.jpg
# Processing frame 4128.jpg
# Processing frame 4129.jpg
# Processing frame 4130.jpg
# Processing frame 4131.jpg
# Processing frame 4132.jpg
# Processing frame 4133.jpg
# Processing frame 4134.jpg
# Processing frame 4135.jpg
# Processing frame 4136.jpg
# Processing frame 4137.jpg
# Processing frame 4138.jpg
# Processing frame 4139.jpg
# Processing frame 4140.jpg
# Processing frame 4141.jpg
# Processing frame 4142.jpg
# Processing frame 4143.jpg
# Processing frame 4144.jpg
# Processing frame 4145.jpg
# Processing frame 4146.jpg
# Processing frame 4147.jpg
# Processing frame 4148.jpg
# Processing frame 4149.jpg
# Processing frame 4150.jpg
# Processing frame 4151.jpg
# Processing frame 4152.jpg
# Processing frame 4153.jpg
# Processing frame 4154.jpg
# Processing frame 4155.jpg
# Processing frame 4156.jpg
# Processing frame 4157.jpg
# Processing frame 4158.jpg
# Processing frame 4159.jpg
# Processing frame 4160.jpg
# Processing frame 4161.jpg
# Processing frame 4162.jpg
# Processing frame 4163.jpg
# Processing frame 4164.jpg
# Processing frame 4165.jpg
# Processing frame 4166.jpg
# Processing frame 4167.jpg
# Processing frame 4168.jpg
# Processing frame 4169.jpg
# Processing frame 4170.jpg
# Processing frame 4171.jpg
# Processing frame 4172.jpg
# Processing frame 4173.jpg
# Processing frame 4174.jpg
# Processing frame 4175.jpg
# Processing frame 4176.jpg
# Processing frame 4177.jpg
# Processing frame 4178.jpg
# Processing frame 4179.jpg
# Processing frame 4180.jpg
# Processing frame 4181.jpg
# Processing frame 4182.jpg
# Processing frame 4183.jpg
# Processing frame 4184.jpg
# Processing frame 4185.jpg
# Processing frame 4186.jpg
# Processing frame 4187.jpg
# Processing frame 4188.jpg
# Processing frame 4189.jpg
# Processing frame 4190.jpg
# Processing frame 4191.jpg
# Processing frame 4192.jpg
# Processing frame 4193.jpg
# Processing frame 4194.jpg
# Processing frame 4195.jpg
# Processing frame 4196.jpg
# Processing frame 4197.jpg
# Processing frame 4198.jpg
# Processing frame 4199.jpg
# Processing frame 4200.jpg
# Processing frame 4201.jpg
# Processing frame 4202.jpg
# Processing frame 4203.jpg
# Processing frame 4204.jpg
# Processing frame 4205.jpg
# Processing frame 4206.jpg
# Processing frame 4207.jpg
# Processing frame 4208.jpg
# Processing frame 4209.jpg
# Processing frame 4210.jpg
# Processing frame 4211.jpg
# Processing frame 4212.jpg
# Processing frame 4213.jpg
# Processing frame 4214.jpg
# Processing frame 4215.jpg
# Processing frame 4216.jpg
# Processing frame 4217.jpg
# Processing frame 4218.jpg
# Processing frame 4219.jpg
# Processing frame 4220.jpg
# Processing frame 4221.jpg
# Processing frame 4222.jpg
# Processing frame 4223.jpg
# Processing frame 4224.jpg
# Processing frame 4225.jpg
# Processing frame 4226.jpg
# Processing frame 4227.jpg
# Processing frame 4228.jpg
# Processing frame 4229.jpg
# Processing frame 4230.jpg
# Processing frame 4231.jpg
# Processing frame 4232.jpg
# Processing frame 4233.jpg
# Processing frame 4234.jpg
# Processing frame 4235.jpg
# Processing frame 4236.jpg
# Processing frame 4237.jpg
# Processing frame 4238.jpg
# Processing frame 4239.jpg
# Processing frame 4240.jpg
# Processing frame 4241.jpg
# Processing frame 4242.jpg
# Processing frame 4243.jpg
# Processing frame 4244.jpg
# Processing frame 4245.jpg
# Processing frame 4246.jpg
# Processing frame 4247.jpg
# Processing frame 4248.jpg
# Processing frame 4249.jpg
# Processing frame 4250.jpg
# Processing frame 4251.jpg
# Processing frame 4252.jpg
# Processing frame 4253.jpg
# Processing frame 4254.jpg
# Processing frame 4255.jpg
# Processing frame 4256.jpg
# Processing frame 4257.jpg
# Processing frame 4258.jpg
# Processing frame 4259.jpg
# Processing frame 4260.jpg
# Processing frame 4261.jpg
# Processing frame 4262.jpg
# Processing frame 4263.jpg
# Processing frame 4264.jpg
# Processing frame 4265.jpg
# Processing frame 4266.jpg
# Processing frame 4267.jpg
# Processing frame 4268.jpg
# Processing frame 4269.jpg
# Processing frame 4270.jpg
# Processing frame 4271.jpg
# Processing frame 4272.jpg
# Processing frame 4273.jpg
# Processing frame 4274.jpg
# Processing frame 4275.jpg
# Processing frame 4276.jpg
# Processing frame 4277.jpg
# Processing frame 4278.jpg
# Processing frame 4279.jpg
# Processing frame 4280.jpg
# Processing frame 4281.jpg
# Processing frame 4282.jpg
# Processing frame 4283.jpg
# Processing frame 4284.jpg
# Processing frame 4285.jpg
# Processing frame 4286.jpg
# Processing frame 4287.jpg
# Processing frame 4288.jpg
# Processing frame 4289.jpg
# Processing frame 4290.jpg
# Processing frame 4291.jpg
# Processing frame 4292.jpg
# Processing frame 4293.jpg
# Processing frame 4294.jpg
# Processing frame 4295.jpg
# Processing frame 4296.jpg
# Processing frame 4297.jpg
# Processing frame 4298.jpg
# Processing frame 4299.jpg
# Processing frame 4300.jpg
# Processing frame 4301.jpg
# Processing frame 4302.jpg
# Processing frame 4303.jpg
# Processing frame 4304.jpg
# Processing frame 4305.jpg
# Processing frame 4306.jpg
# Processing frame 4307.jpg
# Processing frame 4308.jpg
# Processing frame 4309.jpg
# Processing frame 4310.jpg
# Processing frame 4311.jpg
# Processing frame 4312.jpg
# Processing frame 4313.jpg
# Processing frame 4314.jpg
# Processing frame 4315.jpg
# Processing frame 4316.jpg
# Processing frame 4317.jpg
# Processing frame 4318.jpg
# Processing frame 4319.jpg
# Processing frame 4320.jpg
# Processing frame 4321.jpg
# Processing frame 4322.jpg
# Processing frame 4323.jpg
# Processing frame 4324.jpg
# Processing frame 4325.jpg
# Processing frame 4326.jpg
# Processing frame 4327.jpg
# Processing frame 4328.jpg
# Processing frame 4329.jpg
# Processing frame 4330.jpg
# Processing frame 4331.jpg
# Processing frame 4332.jpg
# Processing frame 4333.jpg
# Processing frame 4334.jpg
# Processing frame 4335.jpg
# Processing frame 4336.jpg
# Processing frame 4337.jpg
# Processing frame 4338.jpg
# Processing frame 4339.jpg
# Processing frame 4340.jpg
# Processing frame 4341.jpg
# Processing frame 4342.jpg
# Processing frame 4343.jpg
# Processing frame 4344.jpg
# Processing frame 4345.jpg
# Processing frame 4346.jpg
# Processing frame 4347.jpg
# Processing frame 4348.jpg
# Processing frame 4349.jpg
# Processing frame 4350.jpg
# Processing frame 4351.jpg
# Processing frame 4352.jpg
# Processing frame 4353.jpg
# Processing frame 4354.jpg
# Processing frame 4355.jpg
# Processing frame 4356.jpg
# Processing frame 4357.jpg
# Processing frame 4358.jpg
# Processing frame 4359.jpg
# Processing frame 4360.jpg
# Processing frame 4361.jpg
# Processing frame 4362.jpg
# Processing frame 4363.jpg
# Processing frame 4364.jpg
# Processing frame 4365.jpg
# Processing frame 4366.jpg
# Processing frame 4367.jpg
# Processing frame 4368.jpg
# Processing frame 4369.jpg
# Processing frame 4370.jpg
# Processing frame 4371.jpg
# Processing frame 4372.jpg
# Processing frame 4373.jpg
# Processing frame 4374.jpg
# Processing frame 4375.jpg
# Processing frame 4376.jpg
# Processing frame 4377.jpg
# Processing frame 4378.jpg
# Processing frame 4379.jpg
# Processing frame 4380.jpg
# Processing frame 4381.jpg
# Processing frame 4382.jpg
# Processing frame 4383.jpg
# Processing frame 4384.jpg
# Processing frame 4385.jpg
# Processing frame 4386.jpg
# Processing frame 4387.jpg
# Processing frame 4388.jpg
# Processing frame 4389.jpg
# Processing frame 4390.jpg
# Processing frame 4391.jpg
# Processing frame 4392.jpg
# Processing frame 4393.jpg
# Processing frame 4394.jpg
# Processing frame 4395.jpg
# Processing frame 4396.jpg
# Processing frame 4397.jpg
# Processing frame 4398.jpg
# Processing frame 4399.jpg
# Processing frame 4400.jpg
# Processing frame 4401.jpg
# Processing frame 4402.jpg
# Processing frame 4403.jpg
# Processing frame 4404.jpg
# Processing frame 4405.jpg
# Processing frame 4406.jpg
# Processing frame 4407.jpg
# Processing frame 4408.jpg
# Processing frame 4409.jpg
# Processing frame 4410.jpg
# Processing frame 4411.jpg
# Processing frame 4412.jpg
# Processing frame 4413.jpg
# Processing frame 4414.jpg
# Processing frame 4415.jpg
# Processing frame 4416.jpg
# Processing frame 4417.jpg
# Processing frame 4418.jpg
# Processing frame 4419.jpg
# Processing frame 4420.jpg
# Processing frame 4421.jpg
# Processing frame 4422.jpg
# Processing frame 4423.jpg
# Processing frame 4424.jpg
# Processing frame 4425.jpg
# Processing frame 4426.jpg
# Processing frame 4427.jpg
# Processing frame 4428.jpg
# Processing frame 4429.jpg
# Processing frame 4430.jpg
# Processing frame 4431.jpg
# Processing frame 4432.jpg
# Processing frame 4433.jpg
# Processing frame 4434.jpg
# Processing frame 4435.jpg
# Processing frame 4436.jpg
# Processing frame 4437.jpg
# Processing frame 4438.jpg
# Processing frame 4439.jpg
# Processing frame 4440.jpg
# Processing frame 4441.jpg
# Processing frame 4442.jpg
# Processing frame 4443.jpg
# Processing frame 4444.jpg
# Processing frame 4445.jpg
# Processing frame 4446.jpg
# Processing frame 4447.jpg
# Processing frame 4448.jpg
# Processing frame 4449.jpg
# Processing frame 4450.jpg
# Processing frame 4451.jpg
# Processing frame 4452.jpg
# Processing frame 4453.jpg
# Processing frame 4454.jpg
# Processing frame 4455.jpg
# Processing frame 4456.jpg
# Processing frame 4457.jpg
# Processing frame 4458.jpg
# Processing frame 4459.jpg
# Processing frame 4460.jpg
# Processing frame 4461.jpg
# Processing frame 4462.jpg
# Processing frame 4463.jpg
# Processing frame 4464.jpg
# Processing frame 4465.jpg
# Processing frame 4466.jpg
# Processing frame 4467.jpg
# Processing frame 4468.jpg
# Processing frame 4469.jpg
# Processing frame 4470.jpg
# Processing frame 4471.jpg
# Processing frame 4472.jpg
# Processing frame 4473.jpg
# Processing frame 4474.jpg
# Processing frame 4475.jpg
# Processing frame 4476.jpg
# Processing frame 4477.jpg
# Processing frame 4478.jpg
# Processing frame 4479.jpg
# Processing frame 4480.jpg
# Processing frame 4481.jpg
# Processing frame 4482.jpg
# Processing frame 4483.jpg
# Processing frame 4484.jpg
# Processing frame 4485.jpg
# Processing frame 4486.jpg
# Processing frame 4487.jpg
# Processing frame 4488.jpg
# Processing frame 4489.jpg
# Processing frame 4490.jpg
# Processing frame 4491.jpg
# Processing frame 4492.jpg
# Processing frame 4493.jpg
# Processing frame 4494.jpg
# Processing frame 4495.jpg
# Processing frame 4496.jpg
# Processing frame 4497.jpg
# Processing frame 4498.jpg
# Processing frame 4499.jpg
# Processing frame 4500.jpg
# Processing frame 4501.jpg
# Processing frame 4502.jpg
# Processing frame 4503.jpg
# Processing frame 4504.jpg
# Processing frame 4505.jpg
# Processing frame 4506.jpg
# Processing frame 4507.jpg
# Processing frame 4508.jpg
# Processing frame 4509.jpg
# Processing frame 4510.jpg
# Processing frame 4511.jpg
# Processing frame 4512.jpg
# Processing frame 4513.jpg
# Processing frame 4514.jpg
# Processing frame 4515.jpg
# Processing frame 4516.jpg
# Processing frame 4517.jpg
# Processing frame 4518.jpg
# Processing frame 4519.jpg
# Processing frame 4520.jpg
# Processing frame 4521.jpg
# Processing frame 4522.jpg
# Processing frame 4523.jpg
# Processing frame 4524.jpg
# Processing frame 4525.jpg
# Processing frame 4526.jpg
# Processing frame 4527.jpg
# Processing frame 4528.jpg
# Processing frame 4529.jpg
# Processing frame 4530.jpg
# Processing frame 4531.jpg
# Processing frame 4532.jpg
# Processing frame 4533.jpg
# Processing frame 4534.jpg
# Processing frame 4535.jpg
# Processing frame 4536.jpg
# Processing frame 4537.jpg
# Processing frame 4538.jpg
# Processing frame 4539.jpg
# Processing frame 4540.jpg
# Processing frame 4541.jpg
# Processing frame 4542.jpg
# Processing frame 4543.jpg
# Processing frame 4544.jpg
# Processing frame 4545.jpg
# Processing frame 4546.jpg
# Processing frame 4547.jpg
# Processing frame 4548.jpg
# Processing frame 4549.jpg
# Processing frame 4550.jpg
# Processing frame 4551.jpg
# Processing frame 4552.jpg
# Processing frame 4553.jpg
# Processing frame 4554.jpg
# Processing frame 4555.jpg
# Processing frame 4556.jpg
# Processing frame 4557.jpg
# Processing frame 4558.jpg
# Processing frame 4559.jpg
